# %% [markdown]
# # 100_process_small_data
#
# > This notebook loads and processes the toy data we will be using to smoketest fine-tuning the LLMs.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **First, let's load our data into Pandas dataframes and view them to make sure everything works.**

# %%
# Read videos_small.csv into a DataFrame
videos_df = pd.read_csv('../data/raw/videos_small.csv')

# Read comments_small.csv into a DataFrame
comments_df = pd.read_csv('../data/raw/comments_small.csv')

# Read channels_small.csv into a DataFrame
channels_df = pd.read_csv('../data/raw/channels_small.csv')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\1360651689.py:5: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   comments_df = pd.read_csv('../data/raw/comments_small.csv')

# %%
channels_df.head(1)
# Out:
#    viewCount  subscriberCount  hiddenSubscriberCount  videoCount  \
# 0   488833.0          13800.0                      0          17
#
#                   channel_etag                channel_id   channel_title  \
# 0  lWDtFE6IVC1uuJUk6X6nxJM9G5A  UCmY71FGkk5kMwde_TP3KbnQ  Timothy Snyder
#
#   channel_desc          created_date  \
# 0          NaN  2015-06-26T17:31:11Z
#
#                                        channel_thumb  commentCount  \
# 0  https://yt3.ggpht.com/ytc/AAUvwng0F0CDw54Jjqgc...           NaN
#
#    scraped_date
# 0    1611753925

# %%
videos_df.head(1)
# Out:
#       video_id                             video_title      publication_date  \
# 0  -rMfWXkz1OI  Rumored RE4 Remake has been DELAYED!!!  2021-01-23T20:00:01Z
#
#                                    video_description  \
# 0  This segment previously aired on a 01/22/2021 ...
#
#                  channel_id channel_title  viewCount  likeCount  dislikeCount  \
# 0  UCv9X4TbvB6Eo0s7H20abg5g       Tipster       1485       79.0           5.0
#
#    favoriteCount  commentCount                                    video_url  \
# 0              0          45.0  https://www.youtube.com/watch?v=-rMfWXkz1OI
#
#    scraped_date
# 0    1611753925

# %%
comments_df.head(1)
# Out:
#       video_id                                        textDisplay  \
# 0  -rMfWXkz1OI  RE2 was good, RE 3 is trash ( like the origina...
#
#   authorDisplayName                              authorProfileImageUrl  \
# 0       Optimized C  https://yt3.ggpht.com/ytc/AAUvwnjoO4ILJ5f_f1qa...
#
#                                     authorChannelUrl  \
# 0  http://www.youtube.com/channel/UCApmTT4FP_paOo...
#
#             authorChannelId  canRate viewerRating  likeCount  \
# 0  UCApmTT4FP_paOolvEUq3Drw        1         none          0
#
#             publishedAt             updatedAt                  comment_id  \
# 0  2021-01-25T17:23:45Z  2021-01-25T17:25:57Z  UgzxGyGWCRYlN6MsV5l4AaABAg
#
#   parentId moderationStatus  scraped_date                channel_id
# 0      NaN              NaN    1611753925  UCv9X4TbvB6Eo0s7H20abg5g

# %% [markdown]
# Let's see what the shapes of our tables are:

# %%
df_dic = {
    'channels':channels_df, 
    'videos':videos_df,
    'comments':comments_df
}

#Print Dimensions of Dics
print("Shapes: ")
for df in df_dic:
    print(f"{df}: {df_dic[df].shape}")
# Out:
# Shapes:
# channels: (1000, 12)
# videos: (10000, 13)
# comments: (100000, 16)

# %% [markdown]
# ### For the smoketest, we are going to manually label progressive and conservative channels and select a subset of channels and their videos/comments

# %%
np.unique(channels_df['channel_title'])
# Out:
# array(['(Active Research & Informed Opinion)',
#        '13 Questions by Man Transcending', '6oodfella', '71 Republic',
#        "A Legume of One's Own", 'A Voice For Men', 'A2Z TV',
#        'ABitOfBritt', 'ADAM FRIENDED', 'AMTV', 'AQUAMARINEFACE',
#        'ARealSJW', 'ASKDrBrown', 'AT2 Productions', 'AaronClarey',
#        'Aarvoll', 'Abby Parmelee aka Abigail Beverly Hillz',
#        'AbdultheImpailler', 'Abel Bodi', 'Acronym TV',
#        'Acts17Apologetics', 'Actual Justice Warrior', 'Adam Carolla',
#        'AdamKokesh', 'Adrian Salbuchi', 'Adventist Hermes Justin Wilson',
#        'African Diaspora News Insider', 'Against the Odds', 'Age of Age',
#        'AgentOfDoubt', 'AircraftSparky', 'Airliner World & More',
#        'Akilah Obviously', 'Aldus Valor', 'AlfonZo Rachel',
#        'Alien Queen Of Darkness', 'Alizee', 'Alli YAFF',
#        'Allie Beth Stuckey', 'AlphaOmegaSin', 'AlternateFocus',
#        'Amanee Powers', 'America Uncovered', 'American Anarchist',
#        'American Enterprise Institute', 'American Family Studios',
#        'American Thought Leaders - The Epoch Times', 'Americap',
#        'An Ear for Men', 'An0maly - News Analysis & Hip-hop',
#        'Ana K. Peters', 'Anarchapulco', 'Andalusian Project',
#        'Andrea Lausell', 'Andrew Jodon', 'Andy Ngo', 'Anekantavad',
#        'Angelo John Gage', 'Angelsfoodcake96', 'Angie Speaks',
#        'Angry Gay Pope', 'Annabelle Gurwitch', 'AnotherGayAtheist',
#        'Anthony Brian Logan', 'Anthony Magnabosco', 'Anthony Migchels',
#        'Anti Dem', 'Anti-sleeper', 'Antonia Okafor', 'Anything Goes',
#        'Apollonian Germ', 'Arcion', 'ArdentAtheistEmery',
#        'Arielle Scarcella', 'AronRa', 'Arsalan Aslam', 'ArtisanTony',
#        'AsapSCIENCE', 'Ash Hardell', 'Asha Logos', 'Asha Logos LS',
#        'Ashtyn&Jon', 'Asian Andy', 'Asifa Lahore', 'Atheist Edge',
#        'Augustus Sol Invictus', 'Aunt BB', 'Austin Petersen',
#        'Awake Souls', 'Aydin Paladin', 'Ayla Stewart Wife With A Purpose',
#        'Ayn Rand Institute', 'Azdaja', 'BASSFZz', 'BENPAI',
#        'BLACK GODS OF YAHWEH MEDIA', 'BOND: Rebuilding the Man',
#        'Backalley Philosophy', 'BadMouseProductions', 'Badger Badger',
#        'Banana Warrior Princess', 'Barbara4u2c', 'Bart D. Ehrman',
#        "Bat'ko", 'Battening', 'Bay Area Skeptics', 'Bearingcab',
#        'Ben Burgis', 'Ben Shapiro', 'Ben Swann', 'Benji Buckles',
#        'BigCatKayla Livestreams', 'BigLundi', 'BigTibbs78', 'Bigghair',
#        'Bill Ludlow', "Bill O'Reilly", 'Bill Whittle', 'Billy Bong',
#        'Bina Shah', 'BionicDance', 'Bishop Robert Barron',
#        'Bitcoin Uncensored', 'Black Guns Matter', 'Black Pigeon Speaks',
#        'Black Pilled', 'Black and Intellectual', 'Blair Cottrell',
#        'Blaire White', 'Bloggingheads.tv',
#        'Blonde in the Belly of the Beast', 'Bodyposipanda',
#        'Booze and Bullshit Show', 'Brad Impaler', 'Brad Reed',
#        'Brad Thor', 'Brave New Films', 'BraveTheWorld', 'Bre Faucheux',
#        'BrendioEEE', 'Brendon Marotta', 'Bret Weinstein',
#        'Brittany Simon', 'Bro History', 'Bro. Sanchez LIVE!',
#        'Bro. Sanchez TV', 'Brooks Agnew', 'Brother Ernest',
#        'BrownieInTheBin', 'Bruscar', 'Bryce Blankenagel', 'C0nc0rdance',
#        'CAGE', 'CBL Women', 'Caiden Cowger', 'Caleb Maupin',
#        'Candace Owens', 'CapeAndCrown', 'CaptainMikul', 'Carey Wedler',
#        'Carl Gallups', 'Carneval', 'Cassie Jaye', "Cato's Speech",
#        'Censored Movie', 'Chadcast', 'Chamchi Gimbap', 'Channel Jorp',
#        'Chapo Trap House', 'Charles Eisenstein', 'Charles Tew',
#        'Cheshire Cat Studios', 'Chicago Humanities Festival',
#        'Chip Tatum', "Chris D'Elia", 'Chris Ray Gun',
#        'Christians Against Dinosaurs', 'Church Militant', 'CoachDave.TV',
#        'CobaltCatED', 'Coffee Chat', 'Coffee and Nuance',
#        'Cognitive Talks', 'Colion Noir', 'ComicArtistPro Secrets',
#        'Comics MATTER w/Ya Boi Zack', 'Compound Media', 'Comrade Cora',
#        'Comrade Electric', 'Conner Habib', 'Connor Boyack',
#        'Conquering Modernity', 'Conservative Mexican',
#        'ConservativeElite', 'ContraPoints', 'Contrarian Dude',
#        'CoolHardLogic', 'Corbett Report Extras', 'Corinne Forever',
#        'Corin’s WORLD', 'Cracked', 'Craig Reed TCR', 'Creationist Cat',
#        'Cristina Rad', 'Critical Proximity', 'Cuestar', 'CuteFuzzyWeasel',
#        'Cynic In Chief', 'Cynthia G', 'DEEP FAT FRIED', 'DIRE WOLF',
#        'Dakota Hendrix', 'Dale Hurd', 'Dame Pesos', 'Damien AtHope',
#        'Dan Bidondi', 'Dan Bongino', 'Dan Carlin', 'Dan Palladino',
#        'Dane Wigington', 'Daniel Hammarberg', 'Danny Korcz',
#        'DaphneReloaded', 'Darius M', 'DarkMatter2525', 'Darran Kern',
#        'Darrell Becker', 'Dave Smith', 'David Gee', 'David Johnson',
#        'David Lynch Foundation', 'David Pakman Show', 'David Pino',
#        'David Sirota', 'David Swanson', 'David Yeagley',
#        'DeadManAnimations', 'DeflatingAtheism', 'Democracy At Work',
#        'Democracy Now!', 'DemocraticSocialist01', 'Deric Muhammad',
#        'Desus & Mero', 'Deterlucem', "Devil's Advocate",
#        'Digital Hammurabi', 'Dildo Faggins', "Dinesh D'Souza",
#        'Disgruntled Leaf Network', 'Doctor Mike', 'DoctorRandomercam',
#        'Dolphin Radio', 'Douglas Dietrich', 'Dr. David M. Anderson Sr.',
#        'Dr. Faye Snyder', 'Dr. Shiva Ayyadurai', 'Drew Murray',
#        'Drunken Peasants', 'Duerst The Wuerst',
#        'Duke University Sanford School of Public Policy', 'Dylan Marron',
#        'EGGHEADSHOW', 'ERSTE Foundation', 'Earthfiles', 'Ebon Kim',
#        'Ecce Lux LiveStreams', 'Ed Morrissey', 'Edindro Whitehall',
#        'Edward Giles', 'Eldon Taylor', "Elisabeth's philosophy",
#        'Ellen Jones', 'Empire Files', 'EndtimeInc', 'Enigma Seeker',
#        'Eric Weinstein', 'Ernest Hancock', 'EssenceOfThought',
#        'Eurasianist Perspective', 'Evan Balgord', 'Evil Incarnate',
#        'Ex-Muslims of North America', 'Excultbaby', 'FFRF',
#        'FLAT EARTH BROTHERS', 'FUSION', 'Faithless Feminist', 'Fandar II',
#        'Faraday Speaks', "FatKat N' The Lobbyists", 'Felfop Returns',
#        'Feminist Frequency', 'Feminotzi movement', 'Femsplainers',
#        'Fitness Philosopher', 'Flat Earth Aussie Rosco', 'Flat Out Hero',
#        'Fleccas Talks', 'Flex', 'Forbidden Knowledge',
#        'Foundational Future', 'Fox News Insider', 'FoxyJazzabelle',
#        'Frank Jorge', 'Free Man Beyond the Wall Peter R Quinones',
#        'FreedomProject Media', 'FreedomToons', 'Freeman Fly',
#        'Fright Supremacy', 'Fritz Imperial', 'G Man', 'GZERO Media',
#        'GamingAnarchist', 'Gary Owen', 'Gateway Pundit',
#        'GatorTime Archives', 'Gee Dizzle', 'Genetically Modified Skeptic',
#        'Gentle John', 'Geopolitical Futures', 'Gerald Celente',
#        'Gilad Atzmon', 'Globalization1492', 'Gloria Allred',
#        'Godless Engineer', 'GoldSilver (w/ Mike Maloney)',
#        'Govan Kilgour', 'Graham Elwood', 'GrahamHancockDotCom',
#        'GrapplingIgnorance', 'GreatRedMenace', 'Greg Palast',
#        'Greg Stevens', 'Greg and Mitch', 'GreyKnight7777', 'Grim Jim',
#        'Gryffix', 'Guide to Kulchur', 'Gulf City', 'Gwen Olsen',
#        'H. A. Goodman', 'H3 Podcast', 'HOLIDAY', 'HagbardCeline', 'Hakim',
#        'Hal Sparks', 'Halsey News Network', 'Hannah Wallen',
#        'Hannah and Jake', 'Hans Jørgen Lysglimt Johansen',
#        'Happy Humble Hermit', 'Hard Bastard', 'Harry Hubbard',
#        'Hasan Kwame Jeffries', 'HasanAbi',
#        'Hebrews to Negroes TV aka MOSES LEVI', 'Hellbound Heathen',
#        'Helmuth Nyborg', 'Help For The Guildless', 'Hey Dude 77',
#        'HeyThisIsRya', 'High Tory Gang', 'Highly Critical', 'Hip Hughes',
#        'Holy Koolaid', 'Hoppean Snake Memes', 'Howard Bloom', 'Huckabee',
#        'HumanistCommunityOH', 'Hunter Avallone', 'Hype Break',
#        'I Am Incorrigible', 'I Declare War', 'I I', 'IanHarrisComedian',
#        'Iben Thranholm', 'In Defence of Marxism', 'InaneDragon',
#        'Incorrigible Forever', 'Independent Institute',
#        'Independent Thoughts and Words', 'Indivisible Somerville',
#        'Inmendham Videos', 'Innuendo Studios', 'Insane Rat Bloke',
#        'Intercontinental Food Review', 'International Rescue Committee',
#        'Interspecies & Intersectional Justice', 'Iraqveteran8888',
#        'Irshad Manji', 'It Gets Better Project', 'J.G. Michael',
#        'JAYME LOUIS LIARDI', 'JD Shadow', 'JLongbone', 'JRChadwick',
#        'Jack Barnes MRA', 'Jack Donovan', 'Jackson Bird', 'JaclynGlenn',
#        'Jacque Fresco Foundation', 'Jacques Castilo', 'James Bowery',
#        'James Freeman', 'James Morgan', 'James Pesto',
#        'James Von Maxwell', 'Jamie Dlux', 'Jamie Hanshaw',
#        'Jarnefr Waggener', 'Jason Bermas', 'Jason Erb', 'Jason Richwine',
#        'Jay Dyer', 'Jay Smooth', 'Jaye De Black',
#        'Jaye De Black Livestreams 2', 'Jeff Holiday', 'Jeff Rense',
#        'Jennifer Lokken', 'Jesse Kozlowski', 'Jesse Lee Peterson',
#        'Jesse Ventura', 'Jessica Valenti', 'JihadWatchVideo',
#        'Jilly Juice Protocol', 'Jim Lee', 'Jim Sterling', 'Jim The APE',
#        'Jim and Sam Show', 'Jimmy Snow', 'Joey Diaz', 'Joey Diaz Clips',
#        'John B. Wells - Caravan to Midnight', 'John Cedars', 'John Doyle',
#        'John Lott', 'John Stossel', 'John Talks', 'John Taylor Gatto TV',
#        'Jon Doe', 'Jon E', 'Jordan Owen',
#        'Josh Reeves The Global Reality Channel', 'Josh del Sol',
#        'Josie Outlaw', 'Journi', 'Joy Villa', 'JoyCamp', 'Julie Borowski',
#        'JusReign', 'Just Chyna Fox', 'Just a Robot', 'JusticeForNichole',
#        'Justin Murphy', 'KEM 123', 'Ka Paio', 'Kaanfight',
#        'Kalvin Garrah', 'Karin Smith', 'Kat Blaque', 'Kathy Griffin',
#        'Kayla Schierbecker', 'Keith Woods', 'Kero The Wolf',
#        "Kerry Lutz's Financial Survival Network", 'Kevin Barrett',
#        'Kevin P. Miller', 'Kill the State Live Free',
#        'Kingsley L. Dennis', 'Kizzume', 'Kristiina Ojuland', 'Kuanslog',
#        'Kush Freeman', 'Kyle Taftun', 'L.A.R. Movement',
#        'LALO DAGACH PODCAST', 'LFA', 'LSP', 'Lacey Lynn', 'Lady Columbia',
#        'Larken Rose', 'Larry Elder with Epoch Times',
#        'Larry Sharpe, Libertarian', 'LarryCook333', 'Lateef Abdullah',
#        'Laura Eisenhower', 'Laura Loomer', 'Lauren Chen',
#        'Lawful Masses with Leonard French', 'Learn Liberty',
#        'Left Foot Media', 'Legio Christi', 'Lenon Honor',
#        'LessAngryAussie', 'Let The Madness Begin',
#        'Libertarian Revolution', 'Libertarian Socialist Rants',
#        'Liberty Cap Talk Live', 'Liberty Doll', 'Liberty Forum',
#        'Liberty University', 'Liberty.me', 'Lindsay Ellis',
#        'Lindsay Shepherd', 'Lions Of Liberty', 'Lisa Daftari',
#        'Livelife8072', 'Lizz Reptile', 'Lloyd Pye',
#        'Logical Llama and Skeptical Squirrel', 'Loz Unezie', 'LtSarge',
#        'Luis J. Gomez', 'Luke Ford', 'M. Tracey', 'MARTIVS FILIVS',
#        'MB 23', 'MCToon', 'METOKUR', 'MILO', 'MORTradio', 'MR XULSKI',
#        'MR. OBVIOUS', 'MRCTV', 'MTV Impact', 'Mac Clark', 'Mad Blender',
#        'Mad Dog Gil Guillory', 'Maddox', 'Maddy-MWM Media',
#        'Magog of Morskar', 'Magog of Morskar Livestreams',
#        'Malmrose Projects', 'Mancheeze The Great', 'Marc Stevens',
#        'Marianne Williamson', 'Mark Dice', 'Mark Passio', 'Marking Bad',
#        'Martin Brodel', 'Martymer 81', 'Master Zelox', 'Matt Binder',
#        'Matt Christiansen', 'Matt Forney', 'Matt Jarbo', 'Matthew Cooke',
#        'Max Keiser TV', 'Meghan Tonjes', 'Melissa Dykes',
#        'Memorie Holiday', 'Men Are Good!', 'Messy Elliott',
#        'Micah Curtis', 'Micah Hanks', 'Michael Barden', 'Michael Coudrey',
#        'Michael Malice', 'Michael W. Dean', 'Michea B',
#        'Michelle Liberman', 'Mick West', 'Mike Cernovich',
#        'Mike Clelland', 'Mike Nificent', 'Mike Norton', 'Mike Tyson',
#        'Mike Wilkinson', 'Mikkel Clair Nissen', 'Milo Stewart',
#        "Mimir's Head", 'Minnesota Atheists', 'Minnesotaboyy',
#        'MisanthropikOne', 'Misha Griffith', 'Miss London',
#        'Mister Metokur', 'Moderate Rebels', 'Modern-Day Debate',
#        'Monica Ogden', 'Monsieur Z', 'Monster On Sunday', 'Moral_Compass',
#        'Morally Gray', "Morgoth's Review", 'MorgueOfficial', 'Mr TARDIS',
#        'MrKimDotcom', 'MrThuglife404', 'Mrs. Jenny Kiss', 'Ms Shayla',
#        'Ms. Pat', 'MyNameIsJosephine', 'MykeruMedia', 'Mythinformed',
#        'NFKRZ', 'NRA', 'NRATV', 'Naomi Brockwell', 'NapalmThePhoenix',
#        'Natalie Alford', 'NateTalksToYou', 'Nathan Thompson',
#        'Nathaniel Walters', 'NearEDGE', 'Neel Kashkari',
#        'Neptunes Lagoon', 'New Progressive Voice', 'Newsbroke',
#        'Nicholas Lamar Soutter', 'Nick Di Paolo', 'Nicole Arbour',
#        'No B.S.', 'Noah Lugeons', 'Nobody Listens', 'Noel Hand Grenade',
#        'NollaGirl504', 'Non Serviam Media', 'NonCompete',
#        'Notcrossbearer', 'NowThis World', 'ObjectivelyDan', 'Oh My Gazi',
#        'Old Channel', 'Omni Eros Magick Kool-Aid', 'Omni-Eris',
#        'OneSpecies', 'OneWingedChris', 'Oof Curator', 'OpenMind',
#        'Outlaw American', 'Ozymandias Ramses II', 'PHubb', 'PSA Sitch',
#        'PZ Myers', 'PacificJustice', 'Paris Lees', 'Paris Milan',
#        'PateoMediaInter', 'Patty Politics', 'Paul Joseph Watson',
#        'Paul Mladjenovic', 'Paul Nehlen', 'Paul Waggener',
#        'Pax Dickinson', 'Peach Balie', 'Peak Prosperity', 'Peter Coffin',
#        'Phil Ferguson', 'Philip DeFranco', 'Philogynoir', 'PhilosophiCat',
#        'Philosophy Tube', 'PhoenixRising87', 'Phyllis Schlafly Eagles',
#        'Pierce Ellis', 'Pimpmunkx', 'Pineal Express', 'Pixel Pusher',
#        'Platopus', 'Pleb Media', 'Poisoning The Well Live',
#        'Poisoning the Well', 'PoliDice', 'Polinkazh',
#        'Polite Conversations Podcast', 'Political Islam',
#        'Politics and Prose', 'Pop Culture Detective',
#        'Porkins Policy Radio', 'PowerfulJRE', 'Pox Populi', 'Prag',
#        'PragerU', 'Praxgirl', 'Prince of Queens', 'Professor Stick',
#        'Progressive Secular Alliance', 'Project Veritas',
#        'Project Veritas Action', 'Prophet of Zod', 'PsychologicalCynic',
#        'PwnySlaystation01', 'Queer Kid Stuff', 'Queersplaining',
#        'R.C. Apologist', 'RTR TRUTH MEDIA', 'Radical Capitalist',
#        'Radical Reviewer', 'RageAfterStorm Archive NOT Rage', 'Rags',
#        'Raidio1', 'Ralph Nader Radio Hour', 'Ranting Monkey',
#        'Rational Disconnect', 'Raza Rumi official',
#        'Reactionary Coalition', 'ReallyKarel', 'Rebecca Watson',
#        'Red Phoenix Rises', 'Red Pill Religion', 'RedScare TV',
#        'Redacted Tonight', 'Redmond Weissenberger', 'Reds Rhetoric',
#        'Reg Flowers', 'Rekieta Law', 'Rem the Bath Boi', 'Repzion',
#        'Revenge Of The Cis', 'Rich Penney',
#        'Richard Dawkins Foundation for Reason & Science', 'Richard Dolan',
#        'Richard Grove', 'Richard Lewis', 'RichardDWolff',
#        'Right Wing Federation', 'Riley J. Dennis',
#        'Robert Phoenix - The 11th House', 'Robert Reich',
#        'Robert Wallace', 'Robyn Riley', 'Roland S. Martin',
#        'Rollo McFloogle', 'Ron Placone', 'RonPaulLibertyReport',
#        'Roseanne Barr', 'Russell Howard', 'RutherfordInstitute',
#        'Ryoga Vee', 'S-Man Speaks', 'S.B. Alger', 'Sacred Cow BBQ',
#        'Sage Kronsell', 'Sally Hunt', 'Sam Harris', 'SchoolSucksPodcast',
#        'Scriberr TV', 'Seguin Fonseca', 'Shane Killian', 'Sleepy Saxon',
#        'SomeBlackGuy', 'Sonseed', 'Spooky Nukies', 'Status Coup',
#        'Steevon Kooper', 'Super Creative', 'TJump', 'TMM',
#        "TYT's The Conversation", 'TZMOfficialChannel', 'Terry Petersen',
#        'The Alternative Hypothesis', 'The Andrew Schulz',
#        'The Aureus Press', 'The Babscast', 'The Daily Signal',
#        'The Daily Wire', 'The Dick Show', 'The Fine Young Capitalists',
#        'The Fowler Show', 'The Gator Gamer', 'The Godless Iowan',
#        'The Heritage Foundation', 'The Jimmy Dore Show',
#        'The Laughing Scoundrel Podcast',
#        'The Majority Report w/ Sam Seder', 'The Michael Brooks Show',
#        'The Open Scroll', 'The Pink Pill', 'The Rageaholic',
#        'The Rubin Report', 'The Solari Report', 'The Still Report',
#        'TheQuartering', 'ThinkTank', 'ThunderboltsProject',
#        'Timothy Snyder', 'Tipster', 'Toad McKinley', 'Todd Lewis',
#        'Tom Nichols', 'Tom Secker', 'TomWoodsTV', "Tommy C's SFTP",
#        'Tony Kriz', 'ToolTime', 'Traditional Britain Group',
#        'Trae Crowder', 'Transition Radio Show', 'Tree Of Logic',
#        'Triggered Newscast',
#        'Triton Talks Lecture Series at Edmonds College', 'Troy Leavitt',
#        'Truth Teacher2007', 'TruthRadioShow', 'Truthed Ministry',
#        'TrutherTalk', 'Truthstream Media', 'Turd Flinging Monkey',
#        'Turning Point USA', 'Twilight Aeon', 'Tyler Valle',
#        'TylerPreston20', 'Typhonblue', 'UK Column', 'Underhaven',
#        'Undoomed', 'Unnatural Vegan', 'Unquiet Contention',
#        'Unranked Chevron', 'Unworshipediety', 'UpDownMostly',
#        'Upstream Ideas', 'Uwe Boll Raw', 'VICE', 'VICE Life',
#        'Valuetainment', 'VampKandy', 'Vanity von Glow', 'VarmitCoyote',
#        'Vaush', 'Very Bad News', 'Vic Berger',
#        'Video Game Journalism (YTheAlien)', 'Vito',
#        'Voices of Liberty | Liberty-Minded Multi-Channel Network',
#        "Voltaire's Ghost", 'Vox', 'WHY YOU ARE AN IDIOT', 'WHYitBoy',
#        'Wammy', 'WanderingRusski', 'Warcorpse Live', 'WarmPotato',
#        'Warren Meyer',
#        'Watson Institute for International and Public Affairs',
#        'Wayne Allyn Root', 'We Act Radio', 'We Are All Satoshi',
#        'WeAreChange', 'Wealth Power & Influence with Jason Stapleton',
#        'Weebo Jones', 'Westward Thought', "What's HAPAning",
#        'Whiskey Politics with Dave Sussman', 'WhiteRabbitRadioTV',
#        'WhoWhatWhy', 'Wife Material', 'Will Schnack', 'Wisecrack',
#        'Wizard Of Cause', 'Wochit News', 'Wretched', 'Yaron Brook',
#        'YesIamJames', 'YogiOabs', 'YouTube Hero', 'YouTuber Law',
#        "Young America's Foundation", 'Your Boy Pat', 'YourBestPalClint',
#        'YungCrippTV', 'YusefAlTahir', 'Yuval Noah Harari',
#        'Zachrilege Law', 'Zack Kopplin', 'Zak the American',
#        'Zarna Joshi', 'Zennistrad1', 'Zero Books', 'Zinnia Jones',
#        'Zoe Baker', '_jhc', 'aantonop', 'abraham Weizfeld PhD',
#        'ally bee', 'anactualjoke', 'andy nowicki', 'anubis2814',
#        'bane666au', 'bobby feeno', 'bobothursday', 'boundary 2 journal',
#        'brendanmcooney', 'carlos morales', 'chescaleigh', 'chrisiousity',
#        'christophertitustv', 'corbettreport', 'crazypayne93', 'dansavage',
#        'davidcsmalley', 'debbie duran', 'dickmorrisreports', 'dmurphy25',
#        'doooovid', 'dprjones', 'drumr828', 'drwarrenfarrell',
#        'glo merriweather', 'glynos', 'gw3 Extreme2', 'h3h3Productions',
#        'healthyaddict', 'imaslo typer', 'inFact with Brian Dunning',
#        'inmendham', 'isethoriginal', 'jpm', 'lacigreen', 'liamscheff',
#        'marinashutup', 'markksargent', 'mathisen corollary', 'misesmedia',
#        'misterdeity', 'modvideos1', 'nazra7', 'notregme', 'pimpmunk Live',
#        'progressiveatheists', 'pyrrho314', 'rahotep1000', 'ramzpaul',
#        'robert tindall', 'rosa clemente', 'rose patton',
#        'the Bronx Blogger', 'vextaire', 'worldpoliticsgonemad'],
#       dtype=object)

# %% [markdown]
# Right now I will be using 'https://adfontesmedia.com/interactive-media-bias-chart/' and my own knowledge to pick out recognizable channels from the list above.
#
# Right:
# 'American Thought Leaders - The Epoch Times',
# 'Ben Shapiro',
# 'Blaire White',
# 'Candace Owens',
# 'The Daily Wire',
# 'The Rubin Report',
# 'Turning Point USA',
# 'Fox News Insider',
# 'Jesse Lee Peterson',
# 'PragerU',
# 'NRA',
# 'TheQuartering',
# 'The Daily Signal',
# 'WeAreChange',
# 'The Jimmy Dore Show',
# 'Iraqveteran8888'
#
# Left:
# 'AsapSCIENCE',
# 'David Pakman Show',
# "TYT's The Conversation",
# 'The Majority Report w/ Sam Seder',
# 'h3h3Productions',
# 'H3 Podcast',
# 'HasanAbi',
# 'Vox',
# 'VICE',
# 'The Michael Brooks Show',
# 'The Andrew Schulz',
# 'Sam Harris',
# 'Vaush'

# %%
channel_subset = {
    'right':[
        'American Thought Leaders - The Epoch Times',
        'Ben Shapiro',
        'Blaire White',
        'Candace Owens',
        'The Daily Wire',
        'The Rubin Report',
        'Turning Point USA',
        'Fox News Insider',
        'Jesse Lee Peterson',
        'PragerU',
        'NRA',
        'TheQuartering',
        'The Daily Signal',
        'WeAreChange',
        'The Jimmy Dore Show',
        'Iraqveteran8888'
    ],
    'left':[
        'AsapSCIENCE',
        'David Pakman Show',
        "TYT's The Conversation",
        'The Majority Report w/ Sam Seder',
        'h3h3Productions',
        'H3 Podcast',
        'HasanAbi',
        'Vox',
        'VICE',
        'The Michael Brooks Show',
        'The Andrew Schulz',
        'Sam Harris',
        'Vaush'
    ]
}

# %% [markdown]
# After futher assessment I've noticed only a small percentage of scraped channels have comments. :( This means we will have to choose from those channels.
#
# These include:
# 'Tipster', 'TJump', 'TMM', 'Toad McKinley', 'Men Are Good!',
# 'RTR TRUTH MEDIA', 'Tom Secker', "Tommy C's SFTP", 'TomWoodsTV',
# 'Tony Kriz', 'ToolTime', 'The Aureus Press', 'Trae Crowder',
# 'Transition Radio Show', 'Tree Of Logic', 'Triggered Newscast',
# 'TrutherTalk', 'TruthRadioShow', 'Truth Teacher2007',
# 'Turd Flinging Monkey', 'Turning Point USA', 'Pleb Media',
# 'TylerPreston20', "TYT's The Conversation", 'TZMOfficialChannel',
# 'UK Column'
#
# We will have to do some exploration to label them.

# %%
channel_subset_updated = {
       'left': [
              'Tipster', 'TJump',
              'TMM', "Tommy C's SFTP",
              'Trae Crowder',
              "TYT's The Conversation", 
              'TZMOfficialChannel',
              'UK Column'
       ],
       'right': [
              'Men Are Good!', 'Tony Kriz',
              'TomWoodsTV', 'ToolTime',
              'Tree Of Logic',  'Triggered Newscast',
              'TrutherTalk',  'Turning Point USA',
              'TylerPreston20', 
              
              
       ]
}

# %% [markdown]
# Let's make a dataframe of comments.

# %%
right_channels = channels_df.loc[channels_df['channel_title'].isin(channel_subset_updated['right'])]
right_channels['affiliation'] = 'R'
right_channels = right_channels[['channel_id','channel_title', 'affiliation']]
right_channels
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\3201975618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right_channels['affiliation'] = 'R'
#                   channel_id       channel_title affiliation
# 6   UCAlVRoYjDbgLx7j6O2N8-2g       Men Are Good!           R
# 11  UCsgWR55UyAiFarZYl1u1l9Q          TomWoodsTV           R
# 12  UCBYddbOHrbGipDkQtDrJQxA           Tony Kriz           R
# 13  UCsu6NM_ARGWzDwL1C9xEhqA            ToolTime           R
# 18  UCl3RCEtooHD5bhPCHJw3btA       Tree Of Logic           R
# 19  UCLmEFIwfG3HSru_nUgOktGg  Triggered Newscast           R
# 22  UCamIYU1V5mlVPWQtgq-WgUw         TrutherTalk           R
# 26  UCVrK_pMRp_q8IelpfUCTGLQ   Turning Point USA           R
# 28  UCTrjPBx2WY3wsd1OKmMQv8w      TylerPreston20           R

# %%
left_channels = channels_df.loc[channels_df['channel_title'].isin(channel_subset_updated['left'])]
left_channels['affiliation'] = 'L'
left_channels = left_channels[['channel_id','channel_title', 'affiliation']]
left_channels
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\112235245.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left_channels['affiliation'] = 'L'
#                   channel_id           channel_title affiliation
# 1   UCv9X4TbvB6Eo0s7H20abg5g                 Tipster           L
# 2   UCHXrvsK33VUEcpa4Ar0c0Sg                   TJump           L
# 3   UCQb22imbIqKKWOC98C8Rm2A                     TMM           L
# 10  UCzsqJV6eaQPlmaXgmYaw9kw          Tommy C's SFTP           L
# 16  UCTHsQd-vRXK1bp4vpifl6yA            Trae Crowder           L
# 30  UCKw8kdkYfmuNSVehGoDw8Mg  TYT's The Conversation           L
# 31  UCEwoFdqY09VwZFESGZ8Qp4A      TZMOfficialChannel           L
# 32  UCr_dQZ0irQdRiwVatkuHPcA               UK Column           L

# %%
channel_subset_df = pd.concat([right_channels, left_channels])
channel_subset_df
# Out:
#                   channel_id           channel_title affiliation
# 6   UCAlVRoYjDbgLx7j6O2N8-2g           Men Are Good!           R
# 11  UCsgWR55UyAiFarZYl1u1l9Q              TomWoodsTV           R
# 12  UCBYddbOHrbGipDkQtDrJQxA               Tony Kriz           R
# 13  UCsu6NM_ARGWzDwL1C9xEhqA                ToolTime           R
# 18  UCl3RCEtooHD5bhPCHJw3btA           Tree Of Logic           R
# 19  UCLmEFIwfG3HSru_nUgOktGg      Triggered Newscast           R
# 22  UCamIYU1V5mlVPWQtgq-WgUw             TrutherTalk           R
# 26  UCVrK_pMRp_q8IelpfUCTGLQ       Turning Point USA           R
# 28  UCTrjPBx2WY3wsd1OKmMQv8w          TylerPreston20           R
# 1   UCv9X4TbvB6Eo0s7H20abg5g                 Tipster           L
# 2   UCHXrvsK33VUEcpa4Ar0c0Sg                   TJump           L
# 3   UCQb22imbIqKKWOC98C8Rm2A                     TMM           L
# 10  UCzsqJV6eaQPlmaXgmYaw9kw          Tommy C's SFTP           L
# 16  UCTHsQd-vRXK1bp4vpifl6yA            Trae Crowder           L
# 30  UCKw8kdkYfmuNSVehGoDw8Mg  TYT's The Conversation           L
# 31  UCEwoFdqY09VwZFESGZ8Qp4A      TZMOfficialChannel           L
# 32  UCr_dQZ0irQdRiwVatkuHPcA               UK Column           L

# %%
channel_subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 6 to 32
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   channel_id     17 non-null     object
#  1   channel_title  17 non-null     object
#  2   affiliation    17 non-null     object
# dtypes: object(3)
# memory usage: 544.0+ bytes

# %%
videos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           10000 non-null  object
#  1   video_title        10000 non-null  object
#  2   publication_date   10000 non-null  object
#  3   video_description  9530 non-null   object
#  4   channel_id         10000 non-null  object
#  5   channel_title      10000 non-null  object
#  6   viewCount          10000 non-null  int64
#  7   likeCount          9769 non-null   float64
#  8   dislikeCount       9769 non-null   float64
#  9   favoriteCount      10000 non-null  int64
#  10  commentCount       9684 non-null   float64
#  11  video_url          10000 non-null  object
#  12  scraped_date       10000 non-null  int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1015.8+ KB

# %%
channel_subset_with_comments = channels_df.merge(videos_df, on='channel_id',how='inner')
channel_subset_with_comments = channel_subset_with_comments.merge(comments_df, on='video_id', how='left')[['channel_id_x', 'channel_title_x', 'video_id', 'video_title', 'video_description', 'textDisplay', 'comment_id']]

# %%
channel_subset_with_comments = channel_subset_df.merge(videos_df, on='channel_id',how='inner')
channel_subset_with_comments = channel_subset_with_comments.merge(comments_df, on='video_id', how='inner')[['channel_id_x', 'channel_title_x', 'affiliation', 'video_id', 'video_title', 'video_description', 'textDisplay', 'comment_id']]
channel_subset_with_comments
# Out:
#                    channel_id_x channel_title_x affiliation     video_id  \
# 0      UCAlVRoYjDbgLx7j6O2N8-2g   Men Are Good!           R  -T9vHzMdir4
# 1      UCAlVRoYjDbgLx7j6O2N8-2g   Men Are Good!           R  -T9vHzMdir4
# 2      UCAlVRoYjDbgLx7j6O2N8-2g   Men Are Good!           R  -T9vHzMdir4
# 3      UCAlVRoYjDbgLx7j6O2N8-2g   Men Are Good!           R  -T9vHzMdir4
# 4      UCAlVRoYjDbgLx7j6O2N8-2g   Men Are Good!           R  -T9vHzMdir4
# ...                         ...             ...         ...          ...
# 89814  UCr_dQZ0irQdRiwVatkuHPcA       UK Column           L  2yoqlbn9Ts0
# 89815  UCr_dQZ0irQdRiwVatkuHPcA       UK Column           L  2yoqlbn9Ts0
# 89816  UCr_dQZ0irQdRiwVatkuHPcA       UK Column           L  2yoqlbn9Ts0
# 89817  UCr_dQZ0irQdRiwVatkuHPcA       UK Column           L  2yoqlbn9Ts0
# 89818  UCr_dQZ0irQdRiwVatkuHPcA       UK Column           L  2yoqlbn9Ts0
#
#                                             video_title  \
# 0      Women Rally to Close the Gender Death Gap.  NOT.
# 1      Women Rally to Close the Gender Death Gap.  NOT.
# 2      Women Rally to Close the Gender Death Gap.  NOT.
# 3      Women Rally to Close the Gender Death Gap.  NOT.
# 4      Women Rally to Close the Gender Death Gap.  NOT.
# ...                                                 ...
# 89814                 UK Column News - 6th January 2021
# 89815                 UK Column News - 6th January 2021
# 89816                 UK Column News - 6th January 2021
# 89817                 UK Column News - 6th January 2021
# 89818                 UK Column News - 6th January 2021
#
#                                        video_description  \
# 0      Paul, Tom, and Janice discuss a New York Times...
# 1      Paul, Tom, and Janice discuss a New York Times...
# 2      Paul, Tom, and Janice discuss a New York Times...
# 3      Paul, Tom, and Janice discuss a New York Times...
# 4      Paul, Tom, and Janice discuss a New York Times...
# ...                                                  ...
# 89814  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89815  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89816  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89817  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89818  Brian Gerrish, Mike Robinson, Alex Thomson and...
#
#                                              textDisplay  \
# 0      Men&#39;s generally poorer health from stress ...
# 1      Is anyone on gab? I can&#39;t find people ther...
# 2      Life sucks doesn&#39;t it ladies. He just up a...
# 3      I have seen figures that show less death in th...
# 4      &quot;Waiting for the call for women to protec...
# ...                                                  ...
# 89814  @Robert Green exactly, I live within walking d...
# 89815                     wanna discuss clap trap Brian?
# 89816  Which, when answered correctly leads nicely in...
# 89817  WE will end there. Where? Who favoured Helleni...
# 89818  @CC Jelley <br />Your thought wasn&#39;t your ...
#
#                                               comment_id
# 0                             Ugxtc_P8-7EmyHXAaF14AaABAg
# 1                             UgyhGIdaUug-1Ciyfbh4AaABAg
# 2                             UgwGR7A9eYedizYeCGZ4AaABAg
# 3                             UgyIq8h56bQaUI-O55l4AaABAg
# 4                             UgzLSxmvmakux6GzJG14AaABAg
# ...                                                  ...
# 89814  UgzziTnfC9kiB5qsyyF4AaABAg.9IAyyudOaoc9IBX0mIauLj
# 89815  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB9FsByn5z
# 89816  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB91oH6ug6
# 89817  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB-WsSjP9A
# 89818  UgyMI_J6T7goTZJnPiV4AaABAg.9IAyGubnT9t9IBEmGWoewQ
#
# [89819 rows x 8 columns]

# %%
pd.value_counts(channel_subset_with_comments.channel_title_x)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\2079649.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(channel_subset_with_comments.channel_title_x)
# channel_title_x
# Tipster                   26178
# Turning Point USA         24891
# Trae Crowder               8983
# TrutherTalk                6390
# TomWoodsTV                 4946
# TJump                      4241
# TYT's The Conversation     3885
# TMM                        3584
# Tommy C's SFTP             2631
# Triggered Newscast         1638
# UK Column                  1243
# Men Are Good!               520
# TylerPreston20              367
# ToolTime                    160
# TZMOfficialChannel           95
# Tree Of Logic                64
# Tony Kriz                     3
# Name: count, dtype: int64

# %%
channel_subset_with_comments = channel_subset_with_comments.rename(
    columns={'channel_id_x':'channel_id',
             'channel_title_x':'channel_title',
            'textDisplay':'comment_text'}
)
channel_subset_with_comments
# Out:
#                      channel_id  channel_title affiliation     video_id  \
# 0      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 1      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 2      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 3      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 4      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# ...                         ...            ...         ...          ...
# 89814  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 89815  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 89816  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 89817  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 89818  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
#
#                                             video_title  \
# 0      Women Rally to Close the Gender Death Gap.  NOT.
# 1      Women Rally to Close the Gender Death Gap.  NOT.
# 2      Women Rally to Close the Gender Death Gap.  NOT.
# 3      Women Rally to Close the Gender Death Gap.  NOT.
# 4      Women Rally to Close the Gender Death Gap.  NOT.
# ...                                                 ...
# 89814                 UK Column News - 6th January 2021
# 89815                 UK Column News - 6th January 2021
# 89816                 UK Column News - 6th January 2021
# 89817                 UK Column News - 6th January 2021
# 89818                 UK Column News - 6th January 2021
#
#                                        video_description  \
# 0      Paul, Tom, and Janice discuss a New York Times...
# 1      Paul, Tom, and Janice discuss a New York Times...
# 2      Paul, Tom, and Janice discuss a New York Times...
# 3      Paul, Tom, and Janice discuss a New York Times...
# 4      Paul, Tom, and Janice discuss a New York Times...
# ...                                                  ...
# 89814  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89815  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89816  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89817  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 89818  Brian Gerrish, Mike Robinson, Alex Thomson and...
#
#                                             comment_text  \
# 0      Men&#39;s generally poorer health from stress ...
# 1      Is anyone on gab? I can&#39;t find people ther...
# 2      Life sucks doesn&#39;t it ladies. He just up a...
# 3      I have seen figures that show less death in th...
# 4      &quot;Waiting for the call for women to protec...
# ...                                                  ...
# 89814  @Robert Green exactly, I live within walking d...
# 89815                     wanna discuss clap trap Brian?
# 89816  Which, when answered correctly leads nicely in...
# 89817  WE will end there. Where? Who favoured Helleni...
# 89818  @CC Jelley <br />Your thought wasn&#39;t your ...
#
#                                               comment_id
# 0                             Ugxtc_P8-7EmyHXAaF14AaABAg
# 1                             UgyhGIdaUug-1Ciyfbh4AaABAg
# 2                             UgwGR7A9eYedizYeCGZ4AaABAg
# 3                             UgyIq8h56bQaUI-O55l4AaABAg
# 4                             UgzLSxmvmakux6GzJG14AaABAg
# ...                                                  ...
# 89814  UgzziTnfC9kiB5qsyyF4AaABAg.9IAyyudOaoc9IBX0mIauLj
# 89815  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB9FsByn5z
# 89816  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB91oH6ug6
# 89817  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB-WsSjP9A
# 89818  UgyMI_J6T7goTZJnPiV4AaABAg.9IAyGubnT9t9IBEmGWoewQ
#
# [89819 rows x 8 columns]

# %%
channel_subset_with_comments.fillna('', inplace=True)

# %% [markdown]
# We now have a dataframe of comments labeled on being progressive or conservative. We also have video titles and descriptions which can help describe what the comments are talking about. I think that is a really important concept as this might be what dictates our fine-tuning approach.
#
# After a little exploration, it seems like it will be useful to process comments and video descriptions first.
#
# ### **Process comments and video descriptions.**
#
# *Comment's first*

# %%
pd.unique(channel_subset_with_comments['channel_title'])
# Out:
# array(['Men Are Good!', 'TomWoodsTV', 'Tony Kriz', 'ToolTime',
#        'Tree Of Logic', 'Triggered Newscast', 'TrutherTalk',
#        'Turning Point USA', 'TylerPreston20', 'Tipster', 'TJump', 'TMM',
#        "Tommy C's SFTP", 'Trae Crowder', "TYT's The Conversation",
#        'TZMOfficialChannel', 'UK Column'], dtype=object)

# %%
special_char_vals = [i for i in range(32, 48)]+[i for i in range(58, 65)]+[i for i in range(91, 97)]+[i for i in range(123, 127)]
ascii_dict = {}
for i in special_char_vals:
    ascii_dict[f'&#{i};'] = chr(i)

# %%
other_syms = """
&quot;	"	&#34;	quotation mark	u+0022 ISOnum	\0022	\42
&num;	#	&#35;	number sign	u+0023 ISOnum	\0023	\43
&dollar;	$	&#36;	dollar sign	u+0024 ISOnum	\0024	\44
&percnt;	%	&#37;	percent sign	u+0025 ISOnum	\0025	\45
&amp;	&	&#38;	ampersand	u+0026 ISOnum	\0026	\46
&apos;	'	&#39;	apostrophe	u+0027 ISOnum	\0027	\47
&lpar;	(	&#40;	left parenthesis	u+0028 ISOnum	\0028	\50
&rpar;	)	&#41;	right parenthesis	u+0029 ISOnum	\0029	\51
&ast;	*	&#42;	asterisk	u+002A ISOnum	\002a	\52
&plus;	+	&#43;	plus sign	u+002B ISOnum	\002b	\53
&comma;	,	&#44;	comma	u+002C ISOnum	\002c	\54
&minus;	-	&#45;	hyphen-minus	u+002D ISOnum	\002d	\55
&period;	.	&#46;	full stop; period	u+002E ISOnum	\002e	\56
&sol;	/	&#47;	solidus; slash	u+002F ISOnum	\002f	\57
&colon;	:	&#58;	colon	u+003A ISOnum	\003a	\72
&semi;	;	&#59;	semicolon	u+003B ISOnum	\003b	\73
&lt;	<	&#60;	less-than	u+003C ISOnum	\003c	\74
&equals;	=	&#61;	equals	u+003D ISOnum	\003d	\75
&gt;	>	&#62;	greater-than sign	u+003E ISOnum	\003e	\76
&quest;	?	&#63;	question mark	u+003F ISOnum	\003f	\77
&commat;	@	&#64;	at sign; commercial at	u+0040 ISOnum	\0040	\100
&lsqb;	[	&#91;	left square bracket	u+005B ISOnum	\005b	\133
&bsol;	\	&#92;	backslash	u+005C ISOnum	\005c	\134
&rsqb;	]	&#93;	right square bracket	u+005D ISOnum	\005d	\135
&Hat;	^	&#94;	circumflex accent	u+005E ISOnum	\005e	\136
&lowbar;	_	&#95;	low line	u+005F ISOnum	\005f	\137
&grave;	`	&#96;	grave accent	u+0060 ISOnum	\0060	\u0060
&lcub;	{	&#123;	left curly bracket	u+007b ISOnum	\007b	\173
&verbar;	|	&#124;	vertical bar	u+007c ISOnum	\007c	\174
&rcub;
"""
used_arr = other_syms.split('\t')
key = ""
value = ""
dic = {}
for i in range(len(used_arr)):
    if i % 6 == 0:
        key = used_arr[i]
        key = key.replace('\n', '')
        if i != 0:
            key = key[1:]
    elif i % 6 == 1:
        value = used_arr[i]
    else:
        continue
    dic[key]=value

# %%
ascii_dict.update(dic)
    
def replace_ascii_codes(row):
    if type(row) != str:
        row = ''
        return row
    for code, char in ascii_dict.items():
        row = row.replace(code, char)
    return row

# %%
channel_subset_with_comments.comment_text = channel_subset_with_comments.comment_text.map(replace_ascii_codes)
channel_subset_with_comments = channel_subset_with_comments[~channel_subset_with_comments['comment_text'].str.contains('@', na=False)]
#channel_subset_with_comments = channel_subset_with_comments[channel_subset_with_comments['comment_text'] != '']
channel_subset_with_comments.head(3)
# Out:
#                  channel_id  channel_title affiliation     video_id  \
# 0  UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 1  UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 2  UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
#
#                                         video_title  \
# 0  Women Rally to Close the Gender Death Gap.  NOT.
# 1  Women Rally to Close the Gender Death Gap.  NOT.
# 2  Women Rally to Close the Gender Death Gap.  NOT.
#
#                                    video_description  \
# 0  Paul, Tom, and Janice discuss a New York Times...
# 1  Paul, Tom, and Janice discuss a New York Times...
# 2  Paul, Tom, and Janice discuss a New York Times...
#
#                                         comment_text  \
# 0  Men's generally poorer health from stress caus...
# 1  Is anyone on gab? I can't find people there, p...
# 2  Life sucks doesn't it ladies. He just up and d...
#
#                    comment_id
# 0  Ugxtc_P8-7EmyHXAaF14AaABAg
# 1  UgyhGIdaUug-1Ciyfbh4AaABAg
# 2  UgwGR7A9eYedizYeCGZ4AaABAg

# %%
pd.unique(channel_subset_with_comments['channel_title'])
# Out:
# array(['Men Are Good!', 'TomWoodsTV', 'Tony Kriz', 'ToolTime',
#        'Tree Of Logic', 'Triggered Newscast', 'TrutherTalk',
#        'Turning Point USA', 'TylerPreston20', 'Tipster', 'TJump', 'TMM',
#        "Tommy C's SFTP", 'Trae Crowder', "TYT's The Conversation",
#        'TZMOfficialChannel', 'UK Column'], dtype=object)

# %%
import re
def remove_emojis(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U00002702-\U000027B0"  # Dingbat symbols
                           u"\U000024C2-\U0001F251"  # Enclosed characters
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

channel_subset_with_comments['comment_text'] = channel_subset_with_comments['comment_text'].apply(remove_emojis)

def remove_html_tags(text):
    html_tag_pattern = re.compile('<.*?>')
    return html_tag_pattern.sub('', text)

channel_subset_with_comments['comment_text'] = channel_subset_with_comments['comment_text'].apply(remove_html_tags)
channel_subset_with_comments = channel_subset_with_comments.reset_index(drop=True)
channel_subset_with_comments.tail(5)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\782554979.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_subset_with_comments['comment_text'] = channel_subset_with_comments['comment_text'].apply(remove_emojis)
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\782554979.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_subset_with_comments['comment_text'] = channel_subset_with_comments['comment_text'].apply(remove_html_tags)
#                      channel_id channel_title affiliation     video_id  \
# 77028  UCr_dQZ0irQdRiwVatkuHPcA     UK Column           L  2yoqlbn9Ts0
# 77029  UCr_dQZ0irQdRiwVatkuHPcA     UK Column           L  2yoqlbn9Ts0
# 77030  UCr_dQZ0irQdRiwVatkuHPcA     UK Column           L  2yoqlbn9Ts0
# 77031  UCr_dQZ0irQdRiwVatkuHPcA     UK Column           L  2yoqlbn9Ts0
# 77032  UCr_dQZ0irQdRiwVatkuHPcA     UK Column           L  2yoqlbn9Ts0
#
#                              video_title  \
# 77028  UK Column News - 6th January 2021
# 77029  UK Column News - 6th January 2021
# 77030  UK Column News - 6th January 2021
# 77031  UK Column News - 6th January 2021
# 77032  UK Column News - 6th January 2021
#
#                                        video_description  \
# 77028  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77029  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77030  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77031  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77032  Brian Gerrish, Mike Robinson, Alex Thomson and...
#
#                                             comment_text  \
# 77028  Their are lies damn lies and British politicia...
# 77029  So many people with large family & friend netw...
# 77030                     wanna discuss clap trap Brian?
# 77031  Which, when answered correctly leads nicely in...
# 77032  WE will end there. Where? Who favoured Helleni...
#
#                                               comment_id
# 77028  UgzziTnfC9kiB5qsyyF4AaABAg.9IAyyudOaoc9IDbTcSKMxR
# 77029  UgzziTnfC9kiB5qsyyF4AaABAg.9IAyyudOaoc9ICpFxtI6ro
# 77030  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB9FsByn5z
# 77031  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB91oH6ug6
# 77032  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB-WsSjP9A

# %% [markdown]
# ### *Now for the descriptions*

# %%
x = 0
for i in pd.unique(channel_subset_with_comments['video_description']):
    if x > 5:
        break
    print(i)
    x+=1
# Out:
# Paul, Tom, and Janice discuss a New York Times article about widows of COVID-19, noticing its determination to view the deaths of men through a gynocentric lens. Everything is about the suffering of women, even men's deaths. Then we acknowledge the remarkable work of Mark Perry on gender reality, looking at two charts about the gender gap in occupational fatalities, something that occurs year after year with almost zero public notice.
#
# https://www.nytimes.com/2020/12/31/us/covid-widows-deaths.html?smid=fb-nytimes&smtyp=cur&fbclid=IwAR0jevioPHKN5tgCZ5nL_GyRf6UZVgPuC2pi6_5OTQu7PnROhTvTEbhzrg4
#
# https://www.aei.org/carpe-diem/wednesday-evening-links-all-chart-edition/
#
# https://youtu.be/icV-V73ZjRI
#
#
# Tom's Subscribestar
# https://www.subscribestar.com/red-pill-oasis
#
# Tom's Patreon
# https://patreon.com/menaregood
#
# Tom's web site
# https://menaregood.com
#
# Twitter
# @trgolden
#
# Donate
# https://menaregood.com/wordpress/donations
#
# Toms Books info:
# https://menaregood.com/wordpress/tomsbooks
#
#
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# http://amzn.to/2mGdmkm
#
# The Way Men Heal
# http://ow.ly/Vb3g30nNzuO
#
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# http://ow.ly/lAy930nNzzo
#
# Huge Men Are Good Mug
# http://ow.ly/le4O30nNzCr
#
# Men Are Good Hat
# http://ow.ly/dvsl30nNzFt
# Tom, Paul, and Janice interview PhD Candidate Deborah Powney about her research on male victims of domestic violence. Deborah conducted an important survey last year and is now seeking participants for a second survey focusing on coercive control. Coercive control in intimate relationships was criminalized in 2015 in the UK, but society still lacks an understanding of how often male victims experience emotional, psychological, and financial abuse at the hands of their female partners. One of Deborah Powney's life missions is to change that.
#
#
#
# Here is the link to the Male Victims of  Coercive Control survey;
# https://uclan.eu.qualtrics.com/jfe/form/SV_6rEoyAUolAUn8SV
#
# And here is Deborah's twitter:
# http://twitter.com/Firebird_psych
#
#
#
#
# Tom's Subscribestar
# https://www.subscribestar.com/red-pill-oasis
#
# Tom's Patreon
# https://patreon.com/menaregood
#
# Tom's web site
# https://menaregood.com
#
# Twitter  @trgolden
# http://twitter.com/trgolden
#
# Donate
# https://menaregood.com/wordpress/donations
#
# Toms Books info:
# https://menaregood.com/wordpress/tomsbooks
#
#
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# http://amzn.to/2mGdmkm
#
# The Way Men Heal
# http://ow.ly/Vb3g30nNzuO
#
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# http://ow.ly/lAy930nNzzo
#
# Huge Men Are Good Mug
# http://ow.ly/le4O30nNzCr
#
# Men Are Good Hat
# http://ow.ly/dvsl30nNzFt
# Paul, Tom, and Janice discuss how anti-male bias is starkly evident in the decisions and declarations of the United Nations and the World Health Organization with researcher James Nuzzo. James has done the painstaking work of documenting the lack of attention to men's issues at these renowned international bodies, a glaring global empathy gap.
#
# James Nuzzo Twitter
# https://twitter.com/jameslnuzzo?lang=en
#
# Web Site
# https://www.jameslnuzzo.com/
#
# Issue on Masculinity
# https://www.pjp.psychreg.org/december-2020/
#
# James Nuzzo on the UN and WHO
# https://www.pjp.psychreg.org/wp-content/uploads/2020/12/nuzzo-120-150.pdf
#
#
# Tom's Subscribestar
# https://www.subscribestar.com/red-pill-oasis
#
# Tom's Patreon
# https://patreon.com/menaregood
#
# Tom's web site
# https://menaregood.com
#
# Twitter
# @trgolden
#
# Donate
# https://menaregood.com/wordpress/donations
#
# Toms Books info:
# https://menaregood.com/wordpress/tomsbooks
#
#
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# http://amzn.to/2mGdmkm
#
# The Way Men Heal
# http://ow.ly/Vb3g30nNzuO
#
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# http://ow.ly/lAy930nNzzo
#
# Huge Men Are Good Mug
# http://ow.ly/le4O30nNzCr
#
# Men Are Good Hat
# http://ow.ly/dvsl30nNzFt
# Paul, Tom, and Janice discuss a recent triple homicide-suicide in Australia, in which a mother killed her three young children and herself. The gendered double standards of the mainstream media are on full display.
#
# Links:
#
# Story of Boston mother who murdered her two children by throwing them off a parking garage:
# https://www.nbcnews.com/news/us-news/mom-her-two-young-children-die-fall-boston-parking-garage-n1107416
#
#
#
# Story of father who burned his children and wife to death:
#
# https://www.dailymail.co.uk/news/article-8020641/Brisbane-murder-suicide-Father-sets-wife-kids-fire-car-begs-people-not-save-them.html
#
#
# Links to main story:
#
# https://www.abc.net.au/news/2021-01-14/police-at-tullamarine-home-melbourne-four-bodies-found/13057910
#
# https://www.reddit.com/r/melbourne/comments/kxn66a/incredibly_heartwrenching_father_released_without/
#
# https://www.news.com.au/national/victoria/crime/tullamarine-murdersuicide-katie-perinovics-final-months-before-child-murders/news-story/53817f7104d2069ed7262a3087ad7235
#
# https://m.facebook.com/story.php?story_fbid=3526364807480204&id=320810958035621
#
# https://www.dailymail.co.uk/news/article-9146121/Tullamarine-Dad-called-triple-0-wife-kids-died-waiting-police-yard.html
#
# https://www.perthnow.com.au/news/vic/murder-suicide-probed-in-tullamarines-perinovic-family-home-deaths-ng-b881770160z
#
# https://www.dailymail.co.uk/news/article-9151227/Tullamarine-murder-suicide-Mother-Katie-Perinovic-three-children-pictured-deaths.html
#
# Tom's Subscribestar
# https://www.subscribestar.com/red-pill-oasis
#
# Tom's Patreon
# https://patreon.com/menaregood
#
# Tom's web site
# https://menaregood.com
#
# Twitter
# @trgolden
#
# Donate
# https://menaregood.com/wordpress/donations
#
# Toms Books info:
# https://menaregood.com/wordpress/tomsbooks
#
#
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# http://amzn.to/2mGdmkm
#
# The Way Men Heal
# http://ow.ly/Vb3g30nNzuO
#
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# http://ow.ly/lAy930nNzzo
#
# Huge Men Are Good Mug
# http://ow.ly/le4O30nNzCr
#
# Men Are Good Hat
# http://ow.ly/dvsl30nNzFt
# Adam Ragusea, a popular food YouTuber, recently answered a question about why there aren't more prominent female chefs on YouTube. His answer was textbook feminism (too many entitled men taking up space), so Tom, Paul, and Janice thought it worth discussing. Our conclusion: Adam should stick to questions about cooking.
#
#
# https://www.youtube.com/watch?v=hJHMmIYnSoA&feature=emb_logo&fbclid=IwAR3TEMRo-NqRJxbYa-WoxZUoFZWDAMOJ5tJQtZk9SOEeidFzVrg_MrF-4wE
#
#
#
#
# Tom's Subscribestar
# https://www.subscribestar.com/red-pill-oasis
#
# Tom's Patreon
# https://patreon.com/menaregood
#
# Tom's web site
# https://menaregood.com
#
# Twitter
# @trgolden
#
# Donate
# https://menaregood.com/wordpress/donations
#
# Toms Books info:
# https://menaregood.com/wordpress/tomsbooks
#
#
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# http://amzn.to/2mGdmkm
#
# The Way Men Heal
# http://ow.ly/Vb3g30nNzuO
#
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# http://ow.ly/lAy930nNzzo
#
# Huge Men Are Good Mug
# http://ow.ly/le4O30nNzCr
#
# Men Are Good Hat
# http://ow.ly/dvsl30nNzFt
# Paul, Tom, and Janice discuss two recent videos and the astounding stories associated with them. One video is by radical lesbian feminist Sheila Jeffreys, professor of political studies at the U of Melbourne, who argues that everything in our culture, including transgenderism and drag, is an expression of hatred for women, and femininity a socially constructed sign of women's subordination. In contrast, a video by Will Knowland, a teacher at Eton College for boys in the U.K., corrects the myths of feminist orthodoxy, especially that gender is a social construct and that men 'oppress' women. For making this video, and for refusing to take it down from his personal YouTube page, Knowland has recently been fired.
#
# Links:
#
# The Patriarchy Paradox  (Will Knowland)
# https://www.youtube.com/watch?v=wTHgMxQEoPI
#
# Jeffreys   -  https://youtu.be/SSJjbbshXRg
#
# Blog by Sheila Jeffreys: https://filia.org.uk/filia2018/2018/11/1/the-lesbian-revolution-by-sheila-jeffreys
#
# Story about Will Knowland: https://www.dailymail.co.uk/news/article-8997273/Etonians-revolt-teacher-sacked-daring-question-feminist-dogma-toxic-masculinity.html
#
#
# Tom's Subscribestar
# https://www.subscribestar.com/red-pill-oasis
#
# Tom's Patreon
# https://patreon.com/menaregood
#
# Tom's web site
# https://menaregood.com
#
# Twitter
# @trgolden
#
# Donate
# https://menaregood.com/wordpress/donations
#
# Toms Books info:
# https://menaregood.com/wordpress/tomsbooks
#
#
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# http://amzn.to/2mGdmkm
#
# The Way Men Heal
# http://ow.ly/Vb3g30nNzuO
#
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# http://ow.ly/lAy930nNzzo
#
# Huge Men Are Good Mug
# http://ow.ly/le4O30nNzCr
#
# Men Are Good Hat
# http://ow.ly/dvsl30nNzFt

# %%
def remove_url_lines(text):
    lines = text.split('\n')  # Split the text into lines
    new_lines = [line.strip() for line in lines if not re.search(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', line)]
    cleaned = '\n'.join(new_lines)  # Join the lines back into a single string
    return re.sub('\n+', '\n', cleaned)+'\n'

channel_subset_with_comments['video_description'] = channel_subset_with_comments['video_description'].apply(remove_url_lines)

# %%
x = 0
for i in pd.unique(channel_subset_with_comments['video_description']):
    if x > 5:
        break
    print(i)
    x+=1
# Out:
# Paul, Tom, and Janice discuss a New York Times article about widows of COVID-19, noticing its determination to view the deaths of men through a gynocentric lens. Everything is about the suffering of women, even men's deaths. Then we acknowledge the remarkable work of Mark Perry on gender reality, looking at two charts about the gender gap in occupational fatalities, something that occurs year after year with almost zero public notice.
# Tom's Subscribestar
# Tom's Patreon
# Tom's web site
# Twitter
# @trgolden
# Donate
# Toms Books info:
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# The Way Men Heal
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# Huge Men Are Good Mug
# Men Are Good Hat
#
# Tom, Paul, and Janice interview PhD Candidate Deborah Powney about her research on male victims of domestic violence. Deborah conducted an important survey last year and is now seeking participants for a second survey focusing on coercive control. Coercive control in intimate relationships was criminalized in 2015 in the UK, but society still lacks an understanding of how often male victims experience emotional, psychological, and financial abuse at the hands of their female partners. One of Deborah Powney's life missions is to change that.
# Here is the link to the Male Victims of  Coercive Control survey;
# And here is Deborah's twitter:
# Tom's Subscribestar
# Tom's Patreon
# Tom's web site
# Twitter  @trgolden
# Donate
# Toms Books info:
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# The Way Men Heal
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# Huge Men Are Good Mug
# Men Are Good Hat
#
# Paul, Tom, and Janice discuss how anti-male bias is starkly evident in the decisions and declarations of the United Nations and the World Health Organization with researcher James Nuzzo. James has done the painstaking work of documenting the lack of attention to men's issues at these renowned international bodies, a glaring global empathy gap.
# James Nuzzo Twitter
# Web Site
# Issue on Masculinity
# James Nuzzo on the UN and WHO
# Tom's Subscribestar
# Tom's Patreon
# Tom's web site
# Twitter
# @trgolden
# Donate
# Toms Books info:
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# The Way Men Heal
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# Huge Men Are Good Mug
# Men Are Good Hat
#
# Paul, Tom, and Janice discuss a recent triple homicide-suicide in Australia, in which a mother killed her three young children and herself. The gendered double standards of the mainstream media are on full display.
# Links:
# Story of Boston mother who murdered her two children by throwing them off a parking garage:
# Story of father who burned his children and wife to death:
# Links to main story:
# Tom's Subscribestar
# Tom's Patreon
# Tom's web site
# Twitter
# @trgolden
# Donate
# Toms Books info:
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# The Way Men Heal
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# Huge Men Are Good Mug
# Men Are Good Hat
#
# Adam Ragusea, a popular food YouTuber, recently answered a question about why there aren't more prominent female chefs on YouTube. His answer was textbook feminism (too many entitled men taking up space), so Tom, Paul, and Janice thought it worth discussing. Our conclusion: Adam should stick to questions about cooking.
# Tom's Subscribestar
# Tom's Patreon
# Tom's web site
# Twitter
# @trgolden
# Donate
# Toms Books info:
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# The Way Men Heal
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# Huge Men Are Good Mug
# Men Are Good Hat
#
# Paul, Tom, and Janice discuss two recent videos and the astounding stories associated with them. One video is by radical lesbian feminist Sheila Jeffreys, professor of political studies at the U of Melbourne, who argues that everything in our culture, including transgenderism and drag, is an expression of hatred for women, and femininity a socially constructed sign of women's subordination. In contrast, a video by Will Knowland, a teacher at Eton College for boys in the U.K., corrects the myths of feminist orthodoxy, especially that gender is a social construct and that men 'oppress' women. For making this video, and for refusing to take it down from his personal YouTube page, Knowland has recently been fired.
# Links:
# The Patriarchy Paradox  (Will Knowland)
# Tom's Subscribestar
# Tom's Patreon
# Tom's web site
# Twitter
# @trgolden
# Donate
# Toms Books info:
# Swallowed by a Snake: The Gift of the Masculine Side of Healing
# The Way Men Heal
# Helping Mothers be Closer to their Sons: Understanding the Unique World of Boys
# Huge Men Are Good Mug
# Men Are Good Hat

# %%
pd.unique(channel_subset_with_comments['channel_title'])
# Out:
# array(['Men Are Good!', 'TomWoodsTV', 'Tony Kriz', 'ToolTime',
#        'Tree Of Logic', 'Triggered Newscast', 'TrutherTalk',
#        'Turning Point USA', 'TylerPreston20', 'Tipster', 'TJump', 'TMM',
#        "Tommy C's SFTP", 'Trae Crowder', "TYT's The Conversation",
#        'TZMOfficialChannel', 'UK Column'], dtype=object)

# %%
pd.value_counts(channel_subset_with_comments.loc[channel_subset_with_comments['comment_text'] == '']['channel_title'])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\3291122466.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(channel_subset_with_comments.loc[channel_subset_with_comments['comment_text'] == '']['channel_title'])
# channel_title
# Turning Point USA         228
# Trae Crowder              114
# TrutherTalk                92
# Tipster                    58
# TYT's The Conversation     25
# Tommy C's SFTP             11
# UK Column                  10
# Triggered Newscast          8
# TomWoodsTV                  7
# TJump                       5
# Men Are Good!               2
# TylerPreston20              2
# TMM                         2
# Tree Of Logic               1
# Name: count, dtype: int64

# %%
channel_subset_with_comments = channel_subset_with_comments[channel_subset_with_comments.comment_text != '']
channel_subset_with_comments
# Out:
#                      channel_id  channel_title affiliation     video_id  \
# 0      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 1      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 2      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 3      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# 4      UCAlVRoYjDbgLx7j6O2N8-2g  Men Are Good!           R  -T9vHzMdir4
# ...                         ...            ...         ...          ...
# 77028  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 77029  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 77030  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 77031  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
# 77032  UCr_dQZ0irQdRiwVatkuHPcA      UK Column           L  2yoqlbn9Ts0
#
#                                             video_title  \
# 0      Women Rally to Close the Gender Death Gap.  NOT.
# 1      Women Rally to Close the Gender Death Gap.  NOT.
# 2      Women Rally to Close the Gender Death Gap.  NOT.
# 3      Women Rally to Close the Gender Death Gap.  NOT.
# 4      Women Rally to Close the Gender Death Gap.  NOT.
# ...                                                 ...
# 77028                 UK Column News - 6th January 2021
# 77029                 UK Column News - 6th January 2021
# 77030                 UK Column News - 6th January 2021
# 77031                 UK Column News - 6th January 2021
# 77032                 UK Column News - 6th January 2021
#
#                                        video_description  \
# 0      Paul, Tom, and Janice discuss a New York Times...
# 1      Paul, Tom, and Janice discuss a New York Times...
# 2      Paul, Tom, and Janice discuss a New York Times...
# 3      Paul, Tom, and Janice discuss a New York Times...
# 4      Paul, Tom, and Janice discuss a New York Times...
# ...                                                  ...
# 77028  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77029  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77030  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77031  Brian Gerrish, Mike Robinson, Alex Thomson and...
# 77032  Brian Gerrish, Mike Robinson, Alex Thomson and...
#
#                                             comment_text  \
# 0      Men's generally poorer health from stress caus...
# 1      Is anyone on gab? I can't find people there, p...
# 2      Life sucks doesn't it ladies. He just up and d...
# 3      I have seen figures that show less death in th...
# 4      "Waiting for the call for women to protect men...
# ...                                                  ...
# 77028  Their are lies damn lies and British politicia...
# 77029  So many people with large family & friend netw...
# 77030                     wanna discuss clap trap Brian?
# 77031  Which, when answered correctly leads nicely in...
# 77032  WE will end there. Where? Who favoured Helleni...
#
#                                               comment_id
# 0                             Ugxtc_P8-7EmyHXAaF14AaABAg
# 1                             UgyhGIdaUug-1Ciyfbh4AaABAg
# 2                             UgwGR7A9eYedizYeCGZ4AaABAg
# 3                             UgyIq8h56bQaUI-O55l4AaABAg
# 4                             UgzLSxmvmakux6GzJG14AaABAg
# ...                                                  ...
# 77028  UgzziTnfC9kiB5qsyyF4AaABAg.9IAyyudOaoc9IDbTcSKMxR
# 77029  UgzziTnfC9kiB5qsyyF4AaABAg.9IAyyudOaoc9ICpFxtI6ro
# 77030  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB9FsByn5z
# 77031  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB91oH6ug6
# 77032  UgwWdIXwRecT8RRGoZ14AaABAg.9IAyY08RTtV9IB-WsSjP9A
#
# [76468 rows x 8 columns]

# %%
pd.value_counts(channel_subset_with_comments.loc[channel_subset_with_comments['comment_text'] == '']['channel_title'])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_9436\3291122466.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(channel_subset_with_comments.loc[channel_subset_with_comments['comment_text'] == '']['channel_title'])
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Let's export this to work with it in another notebook.

# %%
channel_subset_with_comments.to_csv("../data/cleaned/channel_subset_with_comments.csv", sep=',', index=False)
